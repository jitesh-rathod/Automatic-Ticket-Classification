# %% [markdown]
# ## **Automatic Ticket Classification Case Study**

# %% [markdown]
# # **Introduction**
#
# In this case study, we have created models that can automatically classify customer complaints based on the products and services that the ticket mentions.

# %% [markdown]
# For a financial company, customer complaints carry a lot of importance, as they are often an indicator of the shortcomings in their products and services. If these complaints are resolved efficiently in time, they can bring down customer dissatisfaction to a minimum and retain them with stronger loyalty. This also gives them an idea of how to continuously improve their services to attract more customers.
#
#
#
# These customer complaints are unstructured text data; so, traditionally, companies need to allocate the task of evaluating and assigning each ticket to the relevant department to multiple support employees. This becomes tedious as the company grows and has a large customer base.
#
#
#
# In this case study, you will be working as an NLP engineer for a financial company that wants to automate its customer support tickets system. As a financial company, the firm has many products and services such as credit cards, banking and mortgages/loans.

# %% [markdown]
# ## **Business goal**
#
#
#
# We need to build a model that is able to classify customer complaints based on the products/services. By doing so, you can segregate these tickets into their relevant categories and, therefore, help in the quick resolution of the issue.
#
# You will be doing topic modelling on the <b>.json</b> data provided by the company. Since this data is not labelled, you need to apply NMF to analyse patterns and classify tickets into the following five clusters based on their products/services:
#
# * Credit card / Prepaid card
#
# * Bank account services
#
# * Theft/Dispute reporting
#
# * Mortgages/loans
#
# * Others
#
#
# With the help of topic modelling, you will be able to map each ticket onto its respective department/category. You can then use this data to train any supervised model such as logistic regression, decision tree or random forest. Using this trained model, you can classify any new customer complaint support ticket into its relevant department.

# %% [markdown]
# ##### **Pipelines that needs to be performed:**
#
# You need to perform the following eight major tasks to complete the assignment:
#
# 1.  Data loading
# 2. Text preprocessing
# 3. Exploratory data analysis (EDA)
# 4. Feature extraction
# 5. Topic modelling
# 6. Model building using supervised learning
# 7. Model training and evaluation
# 8. Model inference

# %% [markdown]
# # **Importing The Necessary Libraries**

# %%
import json
import numpy as np
import pandas as pd
import re, nltk, spacy, string
import en_core_web_sm
nlp = en_core_web_sm.load()

#Importing libraries required for the case study and to plot charts
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from plotly.offline import plot
import plotly.graph_objects as go
import plotly.express as px
# %matplotlib inline

#Importing Regular Expressions for String manipulation
import re

# hide warnings
import warnings
warnings.filterwarnings('ignore')

# set options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from pprint import pprint
# !pip install wordcloud
from wordcloud import WordCloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# # **Data Loading**

# %% [markdown]
# The data is in JSON format and we need to convert it to a dataframe.

# %%
root_path = '/content/complaints-2021-05-14_08_16.json'

# %%
# Opening JSON file
f = open(root_path)

# returns JSON object as a dictionary
data = json.load(f)

# %% [markdown]
# # **Data Preparation**
#
#
# Data cleaning operations like filtering text, removing missing values & renaming column headers.

# %%
df=pd.json_normalize(data)

# %%
# Inspect the dataframe to understand the given data.
df.head(10)
# Out:
#                 _index      _type      _id  _score    _source.tags  \
# 0  complaint-public-v2  complaint  3211475     0.0            None
# 1  complaint-public-v2  complaint  3229299     0.0   Servicemember
# 2  complaint-public-v2  complaint  3199379     0.0            None
# 3  complaint-public-v2  complaint  2673060     0.0            None
# 4  complaint-public-v2  complaint  3203545     0.0            None
# 5  complaint-public-v2  complaint  3275312     0.0  Older American
# 6  complaint-public-v2  complaint  3238804     0.0            None
# 7  complaint-public-v2  complaint  3249272     0.0            None
# 8  complaint-public-v2  complaint  3351653     0.0            None
# 9  complaint-public-v2  complaint  3273612     0.0            None
#
#   _source.zip_code _source.complaint_id                       _source.issue  \
# 0            90301              3211475   Attempts to collect debt not owed
# 1            319XX              3229299     Written notification about debt
# 2            77069              3199379  Other features, terms, or problems
# 3            48066              2673060      Trouble during payment process
# 4            10473              3203545                    Fees or interest
# 5            48227              3275312                 Managing an account
# 6            76262              3238804                 Managing an account
# 7            07753              3249272      Trouble during payment process
# 8            60621              3351653                  Closing an account
# 9            99354              3273612                 Managing an account
#
#        _source.date_received _source.state _source.consumer_disputed  \
# 0  2019-04-13T12:00:00-05:00            CA                       N/A
# 1  2019-05-01T12:00:00-05:00            GA                       N/A
# 2  2019-04-02T12:00:00-05:00            TX                       N/A
# 3  2017-09-13T12:00:00-05:00            MI                       N/A
# 4  2019-04-05T12:00:00-05:00            NY                       N/A
# 5  2019-06-13T12:00:00-05:00            MI                       N/A
# 6  2019-05-10T12:00:00-05:00            TX                       N/A
# 7  2019-05-15T12:00:00-05:00            NJ                       N/A
# 8  2019-08-22T12:00:00-05:00            IL                       N/A
# 9  2019-06-11T12:00:00-05:00            WA                       N/A
#
#                _source.product     _source.company_response  \
# 0              Debt collection      Closed with explanation
# 1              Debt collection      Closed with explanation
# 2  Credit card or prepaid card      Closed with explanation
# 3                     Mortgage      Closed with explanation
# 4  Credit card or prepaid card      Closed with explanation
# 5  Checking or savings account  Closed with monetary relief
# 6  Checking or savings account  Closed with monetary relief
# 7                     Mortgage      Closed with explanation
# 8  Checking or savings account      Closed with explanation
# 9  Checking or savings account  Closed with monetary relief
#
#         _source.company _source.submitted_via _source.date_sent_to_company  \
# 0  JPMORGAN CHASE & CO.                   Web    2019-04-13T12:00:00-05:00
# 1  JPMORGAN CHASE & CO.                   Web    2019-05-01T12:00:00-05:00
# 2  JPMORGAN CHASE & CO.                   Web    2019-04-02T12:00:00-05:00
# 3  JPMORGAN CHASE & CO.                   Web    2017-09-14T12:00:00-05:00
# 4  JPMORGAN CHASE & CO.              Referral    2019-04-05T12:00:00-05:00
# 5  JPMORGAN CHASE & CO.              Referral    2019-06-14T12:00:00-05:00
# 6  JPMORGAN CHASE & CO.                 Phone    2019-05-10T12:00:00-05:00
# 7  JPMORGAN CHASE & CO.              Referral    2019-05-21T12:00:00-05:00
# 8  JPMORGAN CHASE & CO.              Referral    2019-08-23T12:00:00-05:00
# 9  JPMORGAN CHASE & CO.              Referral    2019-06-17T12:00:00-05:00
#
#   _source.company_public_response                         _source.sub_product  \
# 0                            None                            Credit card debt
# 1                            None                            Credit card debt
# 2                            None  General-purpose credit card or charge card
# 3                            None                  Conventional home mortgage
# 4                            None  General-purpose credit card or charge card
# 5                            None                            Checking account
# 6                            None                            Checking account
# 7                            None                  Conventional home mortgage
# 8                            None                            Checking account
# 9                            None                            Checking account
#
#   _source.timely                    _source.complaint_what_happened  \
# 0            Yes
# 1            Yes  Good morning my name is XXXX XXXX and I apprec...
# 2            Yes  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3            Yes
# 4            Yes
# 5            Yes
# 6            Yes
# 7            Yes
# 8            Yes
# 9            Yes
#
#                                   _source.sub_issue  \
# 0                                 Debt is not yours
# 1  Didn't receive enough information to verify debt
# 2             Problem with rewards from credit card
# 3                                              None
# 4                         Charged too much interest
# 5                 Problem using a debit or ATM card
# 6                 Problem using a debit or ATM card
# 7                                              None
# 8                       Company closed your account
# 9                                   Cashing a check
#
#   _source.consumer_consent_provided
# 0              Consent not provided
# 1                  Consent provided
# 2                  Consent provided
# 3              Consent not provided
# 4                               N/A
# 5                               N/A
# 6                               N/A
# 7                               N/A
# 8                               N/A
# 9                               N/A

# %%
#print the column names
df.columns
# Out:
# Index(['_index', '_type', '_id', '_score', '_source.tags', '_source.zip_code',
#        '_source.complaint_id', '_source.issue', '_source.date_received',
#        '_source.state', '_source.consumer_disputed', '_source.product',
#        '_source.company_response', '_source.company', '_source.submitted_via',
#        '_source.date_sent_to_company', '_source.company_public_response',
#        '_source.sub_product', '_source.timely',
#        '_source.complaint_what_happened', '_source.sub_issue',
#        '_source.consumer_consent_provided'],
#       dtype='object')

# %%
#Assign new column names
df = df[['_source.complaint_what_happened','_source.product','_source.sub_product',]]
df.head()
# Out:
#                      _source.complaint_what_happened  \
# 0
# 1  Good morning my name is XXXX XXXX and I apprec...
# 2  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3
# 4
#
#                _source.product                         _source.sub_product
# 0              Debt collection                            Credit card debt
# 1              Debt collection                            Credit card debt
# 2  Credit card or prepaid card  General-purpose credit card or charge card
# 3                     Mortgage                  Conventional home mortgage
# 4  Credit card or prepaid card  General-purpose credit card or charge card

# %%
# lets rename the column names to be more read friendly
# we have retained product and sub_product only for verification purpose ,
# these columns will not be used in the Topic modelling
df = df.rename(columns={'_source.complaint_what_happened': 'complaint_text', '_source.product': 'category','_source.sub_product': 'sub_category'})
df.head()
# Out:
#                                       complaint_text  \
# 0
# 1  Good morning my name is XXXX XXXX and I apprec...
# 2  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3
# 4
#
#                       category                                sub_category
# 0              Debt collection                            Credit card debt
# 1              Debt collection                            Credit card debt
# 2  Credit card or prepaid card  General-purpose credit card or charge card
# 3                     Mortgage                  Conventional home mortgage
# 4  Credit card or prepaid card  General-purpose credit card or charge card

# %%
# lets merge the category and sub-category this will help us in deciding the topics after NMF modelling
df['category'] = df['category'] + '+' + df['sub_category']
df = df.drop(['sub_category'],axis= 1)
df.head()
# Out:
#                                       complaint_text  \
# 0
# 1  Good morning my name is XXXX XXXX and I apprec...
# 2  I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 3
# 4
#
#                                             category
# 0                   Debt collection+Credit card debt
# 1                   Debt collection+Credit card debt
# 2  Credit card or prepaid card+General-purpose cr...
# 3                Mortgage+Conventional home mortgage
# 4  Credit card or prepaid card+General-purpose cr...

# %%
# lets check the nan complaints
df.complaint_text.isnull().sum()
# Out:
# 0

# %%
# lets check the empty string complaints
len(df[df['complaint_text']==''])
# Out:
# 57241

# %%
#Assign nan in place of blanks in the complaints column
# lets replace empty complain with nan value
df[df['complaint_text']==''] = np.nan
df.complaint_text.isnull().sum()
# Out:
# 57241

# %%
#Remove all rows where complaints column is nan
# Lets drop all the rows where complaint_text is null
df = df[~df['complaint_text'].isnull()]
df.complaint_text.isnull().sum()
# Out:
# 0

# %% [markdown]
# # **Text Preprocessing**

# %% [markdown]
# ### **Prepare the text for topic modeling**
#
# Once you have removed all the blank complaints, you need to:
#
# * Make the text lowercase
# * Remove text in square brackets
# * Remove punctuation
# * Remove words containing numbers
#
#
# Once you have done these cleaning operations you need to perform the following:
# * Lemmatize the texts
# * Use POS tags to get relevant words from the texts.

# %%
# Write your function here to clean the text and remove all the unnecessary elements.
# Preparing text for Topic modelling
def clean_text(text):
    text = text.lower()  # Make the text lowercase
    text = re.sub('\[.*\]','', text).strip() # Remove text in square brackets
    text = text.translate(str.maketrans('', '', string.punctuation)) # Remove punctuation
    text = re.sub('\S*\d\S*\s*','', text).strip()  # Remove words containing numbers
    return text.strip()

# %%
df.complaint_text = df.complaint_text.apply(lambda x: clean_text(x))
df.complaint_text.head()
# Out:
# 1     good morning my name is xxxx xxxx and i apprec...
# 2     i upgraded my xxxx xxxx card in and was told b...
# 10    chase card was reported on however fraudulent ...
# 11    on while trying to book a xxxx  xxxx  ticket i...
# 14    my grand son give me check for i deposit it in...
# Name: complaint_text, dtype: object

# %%
#Write your function to Lemmatize the texts
# lemmatization
#Function to Lemmatize the texts
stopwords = nlp.Defaults.stop_words
def lemmatizer(text):
    doc = nlp(text)
    sent = [token.lemma_ for token in doc if not token.text in set(stopwords)]
    return ' '.join(sent)

# %%
# Lemmatize the complaints
df['lemma'] =  df.complaint_text.apply(lambda x: lemmatizer(x))
df.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                                              category  \
# 1                    Debt collection+Credit card debt
# 2   Credit card or prepaid card+General-purpose cr...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14       Checking or savings account+Checking account
#
#                                                 lemma
# 1   good morning xxxx xxxx appreciate help stop ch...
# 2   upgrade xxxx xxxx card tell agent upgrade anni...
# 10  chase card report fraudulent application submi...
# 11  try book xxxx   xxxx   ticket come offer apply...
# 14  grand son check deposit chase account fund cle...

# %%
#Create a dataframe('df_clean') that will have only the complaints and the lemmatized complaints
df_clean = df[['complaint_text','lemma','category']]
df_clean.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                                                 lemma  \
# 1   good morning xxxx xxxx appreciate help stop ch...
# 2   upgrade xxxx xxxx card tell agent upgrade anni...
# 10  chase card report fraudulent application submi...
# 11  try book xxxx   xxxx   ticket come offer apply...
# 14  grand son check deposit chase account fund cle...
#
#                                              category
# 1                    Debt collection+Credit card debt
# 2   Credit card or prepaid card+General-purpose cr...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14       Checking or savings account+Checking account

# %%
#Write your function to extract the POS tags NN
def extract_pos_tags(text):
    doc = nlp(text)
    sent = [token.text for token in doc if token.tag_ == 'NN']
    return ' '.join(sent)

# %%
#The clean dataframe should now contain the raw complaint, lemmatized complaint and the complaint after removing POS tags.
df_clean['complaint_POS_removed'] =  df_clean.lemma.apply(lambda x: extract_pos_tags(x))
df_clean.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                                                 lemma  \
# 1   good morning xxxx xxxx appreciate help stop ch...
# 2   upgrade xxxx xxxx card tell agent upgrade anni...
# 10  chase card report fraudulent application submi...
# 11  try book xxxx   xxxx   ticket come offer apply...
# 14  grand son check deposit chase account fund cle...
#
#                                              category  \
# 1                    Debt collection+Credit card debt
# 2   Credit card or prepaid card+General-purpose cr...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14       Checking or savings account+Checking account
#
#                                 complaint_POS_removed
# 1   morning help bank service chase debt verificat...
# 2   card agent upgrade anniversary date change age...
# 10  chase card report application submit identity ...
# 11  book ticket come offer ticket reward card info...
# 14  son deposit chase account fund bank account pa...

# %% [markdown]
# # **Exploratory data analysis (EDA)**

# %% [markdown]
# ### **Exploratory data analysis to get familiar with the data.**
#
# Write the code in this task to perform the following:
#
# *   Visualise the data according to the 'Complaint' character length
# *   Using a word cloud find the top 40 words by frequency among all the articles after processing the text
# *   Find the top unigrams,bigrams and trigrams by frequency among all the complaints after processing the text. ‘

# %%
# Write your code here to visualise the data according to the 'Complaint' character length

plt.figure(figsize=(10,6))
doc_lens = [len(d) for d in df_clean.complaint_POS_removed]
plt.hist(doc_lens, bins = 50)
# Out:
# (array([9.236e+03, 6.356e+03, 2.725e+03, 1.276e+03, 7.570e+02, 2.750e+02,
#         1.500e+02, 7.100e+01, 6.300e+01, 3.900e+01, 3.700e+01, 1.300e+01,
#         1.100e+01, 1.100e+01, 8.000e+00, 8.000e+00, 7.000e+00, 2.000e+00,
#         3.000e+00, 3.000e+00, 7.000e+00, 2.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 2.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 4.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([    0. ,   248.5,   497. ,   745.5,   994. ,  1242.5,  1491. ,
#          1739.5,  1988. ,  2236.5,  2485. ,  2733.5,  2982. ,  3230.5,
#          3479. ,  3727.5,  3976. ,  4224.5,  4473. ,  4721.5,  4970. ,
#          5218.5,  5467. ,  5715.5,  5964. ,  6212.5,  6461. ,  6709.5,
#          6958. ,  7206.5,  7455. ,  7703.5,  7952. ,  8200.5,  8449. ,
#          8697.5,  8946. ,  9194.5,  9443. ,  9691.5,  9940. , 10188.5,
#         10437. , 10685.5, 10934. , 11182.5, 11431. , 11679.5, 11928. ,
#         12176.5, 12425. ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# #### **Find the top 40 words by frequency among all the articles after processing the text.**

# %%
#Using a word cloud find the top 40 words by frequency among all the articles after processing the text
wordcloud = WordCloud(stopwords=stopwords,max_words=40).generate(str(df_clean.complaint_POS_removed))

print(wordcloud)
plt.figure(figsize=(10,6))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7cf20332b1f0>

# %%
#Removing -PRON- from the text corpus
df_clean['Complaint_clean'] = df_clean['complaint_POS_removed'].str.replace('-PRON-', '')
df_clean = df_clean.drop(['complaint_POS_removed'],axis = 1)

# %% [markdown]
# # **Find the top unigrams,bigrams and trigrams by frequency among all the complaints after processing the text.**

# %%
# Write your code here to find the top 30 unigram,bigram,trigram frequency
# among the complaints in the cleaned datafram(df_clean).

def get_top_n_bigram(text, ngram=1, top=None):
    vec = CountVectorizer(ngram_range=(ngram, ngram), stop_words='english').fit(text)
    bag_of_words = vec.transform(text)

    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]

    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:top]

# %%
top_30_unigrams = get_top_n_bigram(df_clean.Complaint_clean,ngram=1, top=30)
top_30_bigrams = get_top_n_bigram(df_clean.Complaint_clean,ngram=2, top=30)
top_30_trigrams = get_top_n_bigram(df_clean.Complaint_clean,ngram=3, top=30)

# %%
#Print the top 10 words in the unigram frequency
print('Top 10 unigrams:\n')
top_30_unigrams[:10]
# Out:
# Top 10 unigrams:
# [('chase', 53419),
#  ('account', 40961),
#  ('credit', 33554),
#  ('xxxx', 31291),
#  ('card', 29835),
#  ('payment', 21064),
#  ('bank', 17038),
#  ('time', 15871),
#  ('charge', 15292),
#  ('day', 12831)]

# %%
# Top_30_unigrams is already defined as a list of tuples or similar structure
df1 = pd.DataFrame(top_30_unigrams, columns=['unigram', 'count'])

# Plot bar graph for the top 30 words in the unigram frequency
fig = px.bar(df1, x='unigram', y='count',
             title='Top 30 Unigrams Frequency',
             labels={'unigram': 'Unigram', 'count': 'Frequency'},
             color='count',
             color_continuous_scale=px.colors.sequential.Viridis)

# Update layout for better visibility
fig.update_layout(xaxis_tickangle=-80)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1fb8c3f8-926f-49f2-b33f-74c4a46c1d5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fb8c3f8-926f-49f2-b33f-74c4a46c1d5a")) {                    Plotly.newPlot(                        "1fb8c3f8-926f-49f2-b33f-74c4a46c1d5a",                        [{"alignmentgroup":"True","hovertemplate":"Unigram=%{x}\u003cbr\u003eFrequency=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[53419,40961,33554,31291,29835,21064,17038,15871,15292,12831,11793,11145,10369,10278,9459,9201,8865,8584,8571,8439,8225,8178,8032,8007,7724,7709,7636,7609,7548,7533],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["chase","account","credit","xxxx","card","payment","bank","time","charge","day","money","check","loan","report","information","letter","fee","number","state","month","year","xxxxxxxx","customer","pay","dispute","mortgage","balance","transaction","contact","phone"],"xaxis":"x","y":[53419,40961,33554,31291,29835,21064,17038,15871,15292,12831,11793,11145,10369,10278,9459,9201,8865,8584,8571,8439,8225,8178,8032,8007,7724,7709,7636,7609,7548,7533],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outl ...

# %%
#Print the top 10 words in the bigram frequency
print('Top 10 bigrams:\n')
top_30_bigrams[:10]
# Out:
# Top 10 bigrams:
# [('credit card', 12773),
#  ('credit report', 3893),
#  ('chase credit', 3070),
#  ('customer service', 2923),
#  ('account chase', 2432),
#  ('chase bank', 2120),
#  ('check account', 2113),
#  ('chase account', 2034),
#  ('xxxx xxxx', 1954),
#  ('contact chase', 1893)]

# %%
# Top_30_bigrams is already defined as a list of tuples or similar structure
df2 = pd.DataFrame(top_30_bigrams, columns=['bigram', 'count'])

# Plot bar graph for the top 30 words in the bigram frequency
fig = px.bar(df2, x='bigram', y='count',
             title='Top 30 Bigrams Frequency',
             labels={'bigram': 'Bigram', 'count': 'Frequency'},
             color='count',
             color_continuous_scale=px.colors.sequential.Viridis)

# Update layout for better visibility
fig.update_layout(xaxis_tickangle=-80)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="87b22db7-3836-4133-a337-08692b859b18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87b22db7-3836-4133-a337-08692b859b18")) {                    Plotly.newPlot(                        "87b22db7-3836-4133-a337-08692b859b18",                        [{"alignmentgroup":"True","hovertemplate":"Bigram=%{x}\u003cbr\u003eFrequency=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[12773,3893,3070,2923,2432,2120,2113,2034,1954,1893,1881,1701,1617,1603,1570,1546,1534,1534,1369,1242,1195,1141,1137,1135,1130,1121,1096,1096,1083,1070],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["credit card","credit report","chase credit","customer service","account chase","chase bank","check account","chase account","xxxx xxxx","contact chase","debit card","credit score","bank account","account account","number xxxx","chase card","card chase","card account","xxxx credit","phone number","account credit","letter chase","business day","money account","chase customer","credit account","card company","account number","payment chase","payment payment"],"xaxis":"x","y":[12773,3893,3070,2923,2432,2120,2113,2034,1954,1893,1881,1701,1617,1603,1570,1546,1534,1534,1369,1242,1195,1141,1137,1135,1130,1121,1096,1096,1083,1070],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555555 ...

# %%
#Print the top 10 words in the trigram frequency
print('Top 10 trigrams:\n')
top_30_trigrams[:10]
# Out:
# Top 10 trigrams:
# [('chase credit card', 2196),
#  ('credit card account', 1050),
#  ('credit card company', 978),
#  ('credit card chase', 738),
#  ('xxxx credit card', 653),
#  ('chase customer service', 559),
#  ('inquiry credit report', 483),
#  ('credit card credit', 437),
#  ('charge credit card', 406),
#  ('credit card xxxx', 386)]

# %%
# top_30_trigrams is already defined as a list of tuples or similar structure
df3 = pd.DataFrame(top_30_trigrams, columns=['trigram', 'count'])

# Plot bar graph for the top 30 words in the trigram frequency
fig = px.bar(df3, x='trigram', y='count',
             title='Top 30 Trigrams Frequency',
             labels={'trigram': 'Trigram', 'count': 'Frequency'},
             color='count',
             color_continuous_scale=px.colors.sequential.Viridis)

# Update layout for better visibility
fig.update_layout(xaxis_tickangle=-80)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="da17437a-589b-40b4-9935-905a918d76dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da17437a-589b-40b4-9935-905a918d76dd")) {                    Plotly.newPlot(                        "da17437a-589b-40b4-9935-905a918d76dd",                        [{"alignmentgroup":"True","hovertemplate":"Trigram=%{x}\u003cbr\u003eFrequency=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[2196,1050,978,738,653,559,483,437,406,386,381,358,330,309,297,290,280,273,269,244,241,236,235,230,226,224,220,217,214,213],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["chase credit card","credit card account","credit card company","credit card chase","xxxx credit card","chase customer service","inquiry credit report","credit card credit","charge credit card","credit card xxxx","credit reporting agency","account credit card","card credit card","credit report credit","credit card charge","credit card payment","customer service representative","chase auto finance","chase card service","account number xxxx","bank credit card","xxxx xxxx xxxx","freedom credit card","account credit report","credit card balance","credit card service","credit report chase","credit reporting act","chase checking account","credit card statement"],"xaxis":"x","y":[2196,1050,978,738,653,559,483,437,406,386,381,358,330,309,297,290,280,273,269,244,241,236,235,230,226,224,220,217,214,213],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d08 ...

# %% [markdown]
# #### **The personal details of customer has been masked in the dataset with xxxx. Let's remove the masked text as this will be of no use for our analysis**

# %%
df_clean['Complaint_clean'] = df_clean['Complaint_clean'].str.replace('xxxx','')

# %%
#All masked texts has been removed
df_clean.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                                                 lemma  \
# 1   good morning xxxx xxxx appreciate help stop ch...
# 2   upgrade xxxx xxxx card tell agent upgrade anni...
# 10  chase card report fraudulent application submi...
# 11  try book xxxx   xxxx   ticket come offer apply...
# 14  grand son check deposit chase account fund cle...
#
#                                              category  \
# 1                    Debt collection+Credit card debt
# 2   Credit card or prepaid card+General-purpose cr...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14       Checking or savings account+Checking account
#
#                                       Complaint_clean
# 1   morning help bank service chase debt verificat...
# 2   card agent upgrade anniversary date change age...
# 10  chase card report application submit identity ...
# 11  book ticket come offer ticket reward card info...
# 14  son deposit chase account fund bank account pa...

# %% [markdown]
# # **Feature Extraction**

# %% [markdown]
# ### **Convert the raw texts to a matrix of TF-IDF features**
#
# - **max_df** is used for removing terms that appear too frequently, also known as "corpus-specific stop words"
# max_df = 0.95 means "ignore terms that appear in more than 95% of the complaints"
#
# - **min_df** is used for removing terms that appear too infrequently
# min_df = 2 means "ignore terms that appear in less than 2 complaints"

# %%
#Write your code here to initialise the TfidfVectorizer
tfidf = TfidfVectorizer(min_df=2, max_df=0.95, stop_words='english')

# %% [markdown]
# #### **Create a document term matrix using fit_transform**
#
# The contents of a document term matrix are tuples of (complaint_id,token_id) tf-idf score:
# The tuples that are not there have a tf-idf score of 0

# %%
#Write your code here to create the Document Term Matrix by transforming the complaints column present in df_clean.
dtm = tfidf.fit_transform(df_clean.Complaint_clean)

# %%
tfidf.get_feature_names_out()[:10]
# Out:
# array(['aarp', 'abandonment', 'abatement', 'abbreviation', 'abd',
#        'abhorrent', 'abide', 'ability', 'abovementione', 'abovereference'],
#       dtype=object)

# %%
len(tfidf.get_feature_names_out())
# Out:
# 6484

# %% [markdown]
# # **Topic Modelling**

# %% [markdown]
# ## **Topic Modelling using NMF**
#
# - ### **Non-Negative Matrix Factorization (NMF)**
# It is an unsupervised technique so there are no labeling of topics that the model will be trained on. The way it works is that, NMF decomposes (or factorizes) high-dimensional vectors into a lower-dimensional representation. These lower-dimensional vectors are non-negative which also means their coefficients are non-negative.
#
# - In this task we are performing the following:
#
#  * Find the best number of clusters
#  * Apply the best number to create word clusters
#  * Inspect & validate the correction of each cluster wrt the complaints
#  * Correct the labels if needed
#  * Map the clusters to topics/cluster names

# %%
from sklearn.decomposition import NMF

# %% [markdown]
# ## **Manual Topic Modeling**
#  - You need to do take the trial & error approach to find the best num of topics for your NMF model.
#
#  - The only parameter that is required is the number of components i.e. the number of topics we want. This is the most crucial step in the whole topic modeling process and will greatly affect how good your final topics are.

# %%
#Load your nmf_model with the n_components i.e 5
num_topics =  5

#keep the random_state =40
nmf_model = NMF(n_components=num_topics, random_state=40)

W1 = nmf_model.fit_transform(dtm)
H1 = nmf_model.components_

# %%
#Print the Top15 words for each of the topics
num_words=15

vocab = np.array(tfidf.get_feature_names_out())

top_words = lambda t: [vocab[i] for i in np.argsort(t)[:-num_words-1:-1]]
topic_words = ([top_words(t) for t in H1])
topics = [' '.join(t) for t in topic_words]

# %%
vocab
# Out:
# array(['aarp', 'abandonment', 'abatement', ..., 'zombie', 'zone', 'zoom'],
#       dtype=object)

# %%
topics
# Out:
# ['account check money bank deposit chase fund day branch transfer number business transaction customer claim',
#  'card credit chase balance account score limit year purchase point month application service reason time',
#  'payment loan mortgage chase month modification time home pay year rate balance property statement date',
#  'report inquiry credit information company reporting debt account file identity remove dispute theft score letter',
#  'charge dispute fee chase transaction merchant claim purchase refund fraud service email time contact statement']

# %%
#Create the best topic for each complaint in terms of integer value 0,1,2,3 & 4
colnames = ["Topic" + str(i) for i in range(nmf_model.n_components)]
docnames = ["Doc" + str(i) for i in range(len(df_clean.Complaint_clean))]
df_doc_topic = pd.DataFrame(np.round(W1, 2), columns=colnames, index=docnames)
significant_topic = np.argmax(df_doc_topic.values, axis=1)
df_doc_topic['dominant_topic'] = significant_topic
df_doc_topic.head()
# Out:
#       Topic0  Topic1  Topic2  Topic3  Topic4  dominant_topic
# Doc0    0.03    0.00    0.02    0.02    0.01               0
# Doc1    0.01    0.02    0.00    0.00    0.01               1
# Doc2    0.00    0.03    0.00    0.04    0.00               3
# Doc3    0.02    0.03    0.01    0.05    0.01               3
# Doc4    0.07    0.00    0.01    0.00    0.00               0

# %%
#Assign the best topic to each of the cmplaints in Topic Column
df_clean['Topic'] = significant_topic

# %%
df_clean[['complaint_text','Complaint_clean','category','Topic']][df_clean.Topic==4].head(30)
# Out:
#                                         complaint_text  \
# 21   on xxxx i made a payment to an online retailer...
# 30   to whom it may concern chase bank charged wron...
# 40   xxxx xxxx a sofa love seat table and chairs an...
# 45   i made a purchase with xxxx xxxx xxxx on in th...
# 48   jp morgan chase bank please answer the followi...
# 63   i tried to send almost at xxxx and the transac...
# 78   my dispute is for not receiving services liste...
# 88   i preordered an item on xxxxxxxx and paid with...
# 101  i purchase is an airline ticket on xxxxxxxx an...
# 129  this complaint is a follow up regarding a comp...
# 130  i purchased tickets  using my xxxx xxxx xxxx c...
# 138  on i submitted a complaint to my bank jp morga...
# 157  xxxx  has taken or cleaned out all of my funds...
# 160  on more than one occasion my bank  chase  has ...
# 177  i noticed a suspicious charge on my account in...
# 178  when booking a hotel with xxxx i checked the p...
# 196  chase bank refuses to reverse a completely fra...
# 198  i overdrew my account due to errors related to...
# 210  on a technical training company charged my deb...
# 215  on my chase sapphire credit card received a ch...
# 228  to supervisor i wish to make a complaint regar...
# 263  xxxx xxxx and xxxx i have recently used my atm...
# 264  over a year ago i paid a year in advance for a...
# 284  i purchased an online ecommerce course in hope...
# 286  jp morgan chase keep putting a charge off from...
# 307  during the month of xxxx i lost my credit card...
# 322  this is related to the transactions charged to...
# 357  i am appalled at this situation with chase i h...
# 359  this is so unfair its also unacceptable and un...
# 367  xxxxxxxx \n\nthis happens regularly \n\nthe ac...
#
#                                        Complaint_clean  \
# 21    payment retailer chase pay website scam websi...
# 30   concern bank overdraft fee alert balance fee b...
# 40   seat table chair deliver debit card charge ban...
# 45    transaction place dispute case chase bank not...
# 48   answer follow question  information   reason a...
# 63   transaction charge receive service refund card...
# 78   dispute service list night city tour tour reas...
# 88   item  chase credit card merchant estimate prod...
# 101  airline ticket  dollar airport call ticket hou...
# 129  complaint file complaint dispute detail laptop...
# 130  purchase ticket  credit card family parent tim...
# 138  charge debit card cancel time date dispute cha...
# 157  fund chase transaction chase checking account ...
# 160  bank chase overdraft fee account way process c...
# 177  charge account amount  email  seller transacti...
# 178  book property list   list feeling book propert...
# 196  charge  contact chase matter charge bill chase...
# 198  overdraw account error overdraft fee fee payme...
# 210  training company charge debit card product req...
# 215  sapphire credit card charge  dispute chase bra...
# 228  supervisor complaint case managment attention ...
# 263  card withdrawal country fee charge country ban...
# 264  year year advance web site host plan month pro...
# 284  ecommerce course hope way store course guru na...
# 286  charge  credit report chargeoff card chase loa...
# 307  month credit card charge account chase contact...
# 322  transaction charge account debit card charge d...
# 357  chase spend month issue resolve point exhaust ...
# 359  nsf fee charge  transaction account payroll de...
# 367   account money charge bank charge overdraft fe...
#
#                                               category  Topic
# 21   Money transfer, virtual currency, or money ser...      4
# 30        Checking or savings account+Checking account      4
# 40        Checking or savings account+Checking account      4
# 45        Checking or savings account+Checking account      4
# 48        Checking or savings account+Checking account      4
# 63        Checking or savings account+Checking account      4
# 78   Credit card or prepaid card+General-purpose cr...      4
# 88   Credit card or prepaid card+General-purpose cr...      4
# 101       Checking or savings account+Checking account      4
# 129  Credit card or prepaid card+General-purpose cr...      4
# 130  Credit card or prepaid card+General-purpose cr...      4
# 138       Checking or savings account+Checking account      4
# 157                   Debt collection+Credit card debt      4
# 160       Checking or savings account+Checking account      4
# 177       Checking or savings account+Checking account      4
# 178  Credit card or prepaid card+General-purpose cr...      4
# 196  Credit card or prepaid card+General-purpose cr...      4
# 198       Checking or savings account+Checking account      4
# 210       Checking or savings account+Checking account      4
# 215  Credit card or prepaid card+General-purpose cr...      4
# 228                              Mortgage+FHA mortgage      4
# 263       Checking or savings account+Checking account      4
# 264                      Debt collection+I do not know      4
# 284       Checking or savings account+Checking account      4
# 286  Credit reporting, credit repair services, or o...      4
# 307  Credit card or prepaid card+General-purpose cr...      4
# 322       Checking or savings account+Checking account      4
# 357       Checking or savings account+Checking account      4
# 359       Checking or savings account+Checking account      4
# 367       Checking or savings account+Checking account      4

# %%
# Print the first 10 Complaint for each of the Topics
temp =df_clean[['complaint_text','Complaint_clean','category','Topic']].groupby('Topic').head(10)
temp.sort_values('Topic')
# Out:
#                                         complaint_text  \
# 1    good morning my name is xxxx xxxx and i apprec...
# 69   someone called stating i had felony committed ...
# 14   my grand son give me check for i deposit it in...
# 17   with out notice jp morgan chase restricted my ...
# 43   chase sent me an email today with the innocuou...
# 42   my card went missing and i didnt realize it un...
# 35   i opened the saving account for the bonus i wa...
# 24   mishandling of this account by chase auto and ...
# 92   in several transactions on my chase checking a...
# 27   i opened an account with chase bank on xxxx an...
# 65   i opened the chasexxxx xxxx rewards credit car...
# 52   my roommate was stealing my chase debit card a...
# 50   i am a senior citizen that has been scammed by...
# 32   my chase amazon card was declined for a cateri...
# 64   chase is marketing credit cards to those of us...
# 23   i have a chase credit card which is incorrectl...
# 93   on we purchased a service with xxxx xxxx xxxx ...
# 94   i am writing you to file a complaint about an ...
# 2    i upgraded my xxxx xxxx card in and was told b...
# 59   i currently have over xxxx chase ultimate rewa...
# 82   i recently called to ask chase bank why they r...
# 81   i bought a new xxxx xxxx on xxxxxxxx from xxxx...
# 73   i have wired through one of chase branches in ...
# 99   my name is xxxx xxxx i have missed a payment i...
# 127  i am xxxx military member  xxxx  with the xxxx...
# 141  action taken by the company between the dates ...
# 86   a student loan with chase bank they sold there...
# 58   i made a purchase of on xxxxxxxx i made paymen...
# 57   i have been trying to do a loan modification w...
# 20   during the summer months i experience a declin...
# 143  hello  i applied for a credit account with ama...
# 10   chase card was reported on however fraudulent ...
# 139  chase im filing a complaint after disputing wi...
# 135  i checked my credit reports and noticed the in...
# 11   on while trying to book a xxxx  xxxx  ticket i...
# 100  i have contacted both chase bank and xxxx xxxx...
# 15                       can you please remove inquiry
# 152  xxxx xxxx xxxx inquiry on xxxxxxxx xxxx  xxxx ...
# 83   unknown inquire reported on my credit bureau s...
# 26   i have reached out to xxxx several times in at...
# 63   i tried to send almost at xxxx and the transac...
# 88   i preordered an item on xxxxxxxx and paid with...
# 30   to whom it may concern chase bank charged wron...
# 101  i purchase is an airline ticket on xxxxxxxx an...
# 40   xxxx xxxx a sofa love seat table and chairs an...
# 129  this complaint is a follow up regarding a comp...
# 45   i made a purchase with xxxx xxxx xxxx on in th...
# 78   my dispute is for not receiving services liste...
# 48   jp morgan chase bank please answer the followi...
# 21   on xxxx i made a payment to an online retailer...
#
#                                        Complaint_clean  \
# 1    morning help bank service chase debt verificat...
# 69   state felony security number  check account as...
# 14   son deposit chase account fund bank account pa...
# 17   account debit card branch customer service rep...
# 43   chase email today title information change cha...
# 42   card today check email deposit money bank account
# 35   bonus auto transfer check saving notice transf...
# 24                       mishandle account chase auto
# 92   transaction chase account file report chase ac...
# 27   account follow  term account  deposit bonus pa...
# 65   chase reward credit card time reward point com...
# 52   roommate chase debit card driver license money...
# 50   citizen time share company misleading refund c...
# 32   catering order place brother contact chase noo...
# 64   chase marketing credit card credit style marke...
# 23   chase credit card datum credit report company ...
# 93   purchase service  group island snorkeling acti...
# 94   file complaint issue credit card chase benefit...
# 2    card agent upgrade anniversary date change age...
# 59    reward point month access chase reward accoun...
# 82   report day payment pay call info balance finis...
# 81   loan release title contact chase time resoluti...
# 73   wire chase branch reinstatement order foreclos...
# 99   payment day current time loan modification los...
# 127  member auto finance pay gap insurancewaiver co...
# 141  action company date group contact chase claim ...
# 86   student loan chase bank sell account  account ...
# 58    payment  payment closing date  statement stat...
# 57                     loan modification chase payment
# 20   summer month experience income employment requ...
# 143  credit account credit credit reporting service...
# 10   chase card report application submit identity ...
# 139  dispute report company time fix problem lawsui...
# 135             credit report inquiry business company
# 11   book ticket come offer ticket reward card info...
# 100  contact bank inquiry initiate company inaccura...
# 15                                             inquiry
# 152                                            inquiry
# 83                    inquire report credit chase auto
# 26   time attempt inquiry remove need contact credi...
# 63   transaction charge receive service refund card...
# 88   item  chase credit card merchant estimate prod...
# 30   concern bank overdraft fee alert balance fee b...
# 101  airline ticket  dollar airport call ticket hou...
# 40   seat table chair deliver debit card charge ban...
# 129  complaint file complaint dispute detail laptop...
# 45    transaction place dispute case chase bank not...
# 78   dispute service list night city tour tour reas...
# 48   answer follow question  information   reason a...
# 21    payment retailer chase pay website scam websi...
#
#                                               category  Topic
# 1                     Debt collection+Credit card debt      0
# 69        Checking or savings account+Checking account      0
# 14        Checking or savings account+Checking account      0
# 17        Checking or savings account+Checking account      0
# 43   Credit card or prepaid card+General-purpose cr...      0
# 42        Checking or savings account+Checking account      0
# 35         Checking or savings account+Savings account      0
# 24                          Vehicle loan or lease+Loan      0
# 92                       Debt collection+I do not know      0
# 27        Checking or savings account+Checking account      0
# 65   Credit card or prepaid card+General-purpose cr...      1
# 52        Checking or savings account+Checking account      1
# 50   Credit card or prepaid card+General-purpose cr...      1
# 32   Credit card or prepaid card+General-purpose cr...      1
# 64   Credit card or prepaid card+General-purpose cr...      1
# 23   Credit card or prepaid card+General-purpose cr...      1
# 93   Credit card or prepaid card+General-purpose cr...      1
# 94   Credit card or prepaid card+General-purpose cr...      1
# 2    Credit card or prepaid card+General-purpose cr...      1
# 59   Credit card or prepaid card+General-purpose cr...      1
# 82                    Debt collection+Credit card debt      2
# 81                          Vehicle loan or lease+Loan      2
# 73   Mortgage+Home equity loan or line of credit (H...      2
# 99                 Mortgage+Conventional home mortgage      2
# 127                         Consumer Loan+Vehicle loan      2
# 141       Checking or savings account+Checking account      2
# 86                   Student loan+Private student loan      2
# 58   Credit card or prepaid card+General-purpose cr...      2
# 57                 Mortgage+Conventional home mortgage      2
# 20                          Vehicle loan or lease+Loan      2
# 143  Credit reporting, credit repair services, or o...      3
# 10   Credit reporting, credit repair services, or o...      3
# 139  Credit card or prepaid card+General-purpose cr...      3
# 135  Credit reporting, credit repair services, or o...      3
# 11   Credit reporting, credit repair services, or o...      3
# 100  Credit reporting, credit repair services, or o...      3
# 15   Credit reporting, credit repair services, or o...      3
# 152  Credit reporting, credit repair services, or o...      3
# 83   Credit reporting, credit repair services, or o...      3
# 26   Credit reporting, credit repair services, or o...      3
# 63        Checking or savings account+Checking account      4
# 88   Credit card or prepaid card+General-purpose cr...      4
# 30        Checking or savings account+Checking account      4
# 101       Checking or savings account+Checking account      4
# 40        Checking or savings account+Checking account      4
# 129  Credit card or prepaid card+General-purpose cr...      4
# 45        Checking or savings account+Checking account      4
# 78   Credit card or prepaid card+General-purpose cr...      4
# 48        Checking or savings account+Checking account      4
# 21   Money transfer, virtual currency, or money ser...      4

# %% [markdown]
# #### **After evaluating the mapping, if the topics assigned are correct then assign these names to the relevant topic:**
# * Bank Account services
# * Credit card or prepaid card
# * Theft/Dispute Reporting
# * Mortgage/Loan
# * Others

# %%
#Create the dictionary of Topic names and Topics
topic_mapping = {
    0: 'Bank Account services',
    1: 'Credit card or prepaid card',
    2: 'Others',
    3: 'Theft/Dispute Reporting',
    4: 'Mortgage/Loan'
}

#Replace Topics with Topic Names
df_clean['Topic'] = df_clean['Topic'].map(topic_mapping)

# %%
df_clean.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                                                 lemma  \
# 1   good morning xxxx xxxx appreciate help stop ch...
# 2   upgrade xxxx xxxx card tell agent upgrade anni...
# 10  chase card report fraudulent application submi...
# 11  try book xxxx   xxxx   ticket come offer apply...
# 14  grand son check deposit chase account fund cle...
#
#                                              category  \
# 1                    Debt collection+Credit card debt
# 2   Credit card or prepaid card+General-purpose cr...
# 10  Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 14       Checking or savings account+Checking account
#
#                                       Complaint_clean  \
# 1   morning help bank service chase debt verificat...
# 2   card agent upgrade anniversary date change age...
# 10  chase card report application submit identity ...
# 11  book ticket come offer ticket reward card info...
# 14  son deposit chase account fund bank account pa...
#
#                           Topic
# 1         Bank Account services
# 2   Credit card or prepaid card
# 10      Theft/Dispute Reporting
# 11      Theft/Dispute Reporting
# 14        Bank Account services

# %% [markdown]
# #### **Lets Check If There Is Any Class Imbalance**

# %%
# Plot graph to check class imbalance
fig = px.histogram(df_clean, x='Topic', title='Class Imbalance - Topic Distribution',
                   labels={'Topic': 'Topic'},
                   color='Topic',
                   color_discrete_sequence=px.colors.qualitative.Set2)

# Update layout for better visibility
fig.update_layout(xaxis_title='Topic', yaxis_title='Count', xaxis_tickangle=-45)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="475eca73-0af3-4332-b722-2b0f9442a1eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("475eca73-0af3-4332-b722-2b0f9442a1eb")) {                    Plotly.newPlot(                        "475eca73-0af3-4332-b722-2b0f9442a1eb",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Topic=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bank Account services","marker":{"color":"rgb(102,194,165)","pattern":{"shape":""}},"name":"Bank Account services","offsetgroup":"Bank Account services","orientation":"v","showlegend":true,"x":["Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services","Bank Account services ...

# %% [markdown]
# # **Model building using supervised learning, Model training & evaluation**

# %% [markdown]
# ## **Supervised Model To Predict Any New Complaints To The Relevant Topics.**
#
# - We now build the model to create the topics for each complaints.Now in the below section you will use them to classify any new complaints.
#
# - Since you will be using supervised learning technique we have to convert the topic names to numbers(numpy arrays only understand numbers)

# %%
#Keep the columns"complaint_what_happened" & "Topic" only in the new dataframe --> training_data

training_data = df_clean[['complaint_text','Topic']]

# %%
training_data.head()
# Out:
#                                        complaint_text  \
# 1   good morning my name is xxxx xxxx and i apprec...
# 2   i upgraded my xxxx xxxx card in and was told b...
# 10  chase card was reported on however fraudulent ...
# 11  on while trying to book a xxxx  xxxx  ticket i...
# 14  my grand son give me check for i deposit it in...
#
#                           Topic
# 1         Bank Account services
# 2   Credit card or prepaid card
# 10      Theft/Dispute Reporting
# 11      Theft/Dispute Reporting
# 14        Bank Account services

# %% [markdown]
# ## **Reverse topic names mapping for supervised learning**

# %%
## Reverse topic names mapping for supervised learning

reverse_topic_mapping = {
    'Bank Account services' :0,
    'Credit card or prepaid card':1,
    'Others':2,
    'Theft/Dispute Reporting':3,
    'Mortgage/Loan':4
}
#Replace Topics with Topic Names
training_data['Topic'] = training_data['Topic'].map(reverse_topic_mapping)
training_data.head()
# Out:
#                                        complaint_text  Topic
# 1   good morning my name is xxxx xxxx and i apprec...      0
# 2   i upgraded my xxxx xxxx card in and was told b...      1
# 10  chase card was reported on however fraudulent ...      3
# 11  on while trying to book a xxxx  xxxx  ticket i...      3
# 14  my grand son give me check for i deposit it in...      0

# %%
training_data[['complaint_text','Topic']][training_data.Topic==2].head(30)
# Out:
#                                         complaint_text  Topic
# 20   during the summer months i experience a declin...      2
# 57   i have been trying to do a loan modification w...      2
# 58   i made a purchase of on xxxxxxxx i made paymen...      2
# 73   i have wired through one of chase branches in ...      2
# 81   i bought a new xxxx xxxx on xxxxxxxx from xxxx...      2
# 82   i recently called to ask chase bank why they r...      2
# 86   a student loan with chase bank they sold there...      2
# 99   my name is xxxx xxxx i have missed a payment i...      2
# 127  i am xxxx military member  xxxx  with the xxxx...      2
# 141  action taken by the company between the dates ...      2
# 156  chase issued a mortgage loan against my proper...      2
# 167  a double payment from my chase debt cart to ch...      2
# 203  jp morgan and chase reported loans   xxxx  xxx...      2
# 213  my mortgage is with chase my payments were bei...      2
# 265  i am submitting a complaint regarding the acti...      2
# 267  i received an offer from chase xxxx visa promi...      2
# 287  i have a chase sapphire reserved card and the ...      2
# 293  i ask chase auto finance please honor the writ...      2
# 294  spoke to the with payment arrangement xxxxxxxx...      2
# 296  claim number xxxx this complaint is in regard ...      2
# 316  re  complaint against jp morgan chase xxxx hom...      2
# 317  ive been actively trying to resolve this conce...      2
# 339  on i purchased a used truck at xxxx at the tim...      2
# 353  my information was used to obtain a loan from ...      2
# 365  jpmorgan chase bank and xxxxxxxx xxxx xxxx xxx...      2
# 382  i want to raise concern due the company not re...      2
# 383  on xxxxxxxx i made an additional principal pay...      2
# 394  i sent to a seller on xxxx for a pair of sneak...      2
# 399  my wife and i have had a traditional xxxx yr m...      2
# 402  i applied for a chase credit card affiliated w...      2

# %% [markdown]
# #### **Apply the supervised models on the training data created. In this process, you have to do the following:**
# * Create the vector counts using Count Vectoriser
# * Transform the word vecotr to tf-idf
# * Create the train & test data using the train_test_split on the tf-idf & topics

# %% [markdown]
# ## **X - Y split**

# %%
# x - y  split
X = training_data.complaint_text
y = training_data.Topic

# %%
#Write your code to get the Vector count

# Fit transform the X
count_vect = CountVectorizer()
X_vect = count_vect.fit_transform(X)

# %%
from sklearn.feature_extraction.text import TfidfTransformer
#Write your code here to transform the word vector to tf-idf
#Fit transform word vector to TF-IDF
tfidf_transformer = TfidfTransformer()
X_tfidf = tfidf_transformer.fit_transform(X_vect)

# %% [markdown]
# ## **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
# train test split
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.25, random_state=40, stratify=y)

# %% [markdown]
# You have to try atleast 3 models on the train & test data from these options:
# #### **We are trying the following models**
# * Logistic regression
# * Decision Tree
# * Random Forest
# * Naive Bayes (optional)
#
# **Using the required evaluation metrics judge the tried models and select the ones performing the best**

# %% [markdown]
# ## **Logistic regression, Decision Tree & Random Forest**

# %%
# Write your code here to build any 3 models and evaluate them using the required metrics

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier


from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_recall_fscore_support

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %% [markdown]
# ## **Custom Classification Report**

# %%
# utlity function to display the model report

def display_classification_report(model,metric):

    y_train_pred_proba = model.predict_proba(X_train)
    y_test_pred_proba = model.predict_proba(X_test)
    roc_auc_score_train = round(roc_auc_score(y_train, y_train_pred_proba,average='weighted',multi_class='ovr'),2)
    roc_auc_score_test = round(roc_auc_score(y_test, y_test_pred_proba,average='weighted',multi_class='ovr'),2)
    print("ROC AUC Score Train:", roc_auc_score_train)
    print("ROC AUC Score Test:", roc_auc_score_test)
    metric.append(roc_auc_score_train)
    metric.append(roc_auc_score_test)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    precision_train,recall_train,fscore_train,support_train=precision_recall_fscore_support(y_train,y_train_pred,average='weighted')
    precision_test,recall_test,fscore_test,support_test=precision_recall_fscore_support(y_test,y_test_pred,average='weighted')

    acc_score_train = round(accuracy_score(y_train,y_train_pred),2)
    acc_score_test = round(accuracy_score(y_test,y_test_pred),2)

    metric.append(acc_score_train)
    metric.append(acc_score_test)
    metric.append(round(precision_train,2))
    metric.append(round(precision_test,2))
    metric.append(round(recall_train,2))
    metric.append(round(recall_test,2))
    metric.append(round(fscore_train,2))
    metric.append(round(fscore_test,2))

    print('Train Accuracy :',acc_score_train)
    print('Test Accuracy :',acc_score_test)

    model_report_train = classification_report(y_train,y_train_pred)
    model_report_test = classification_report(y_test,y_test_pred)

    print('Classification Report for Train:\n',model_report_train)
    print('Classification Report for Test:\n',model_report_test)


    # Plot the confusion matrix
    fig, ax = plt.subplots(figsize=(12, 8))
    # Create the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    cmp = ConfusionMatrixDisplay(cm, display_labels=model.classes_)
    cmp.plot(ax=ax)
    plt.xticks(rotation=80)

    plt.show();

# %% [markdown]
# ## **Stratified KFold Cross Validation**

# %%
# create 5 folds
folds = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 40)

# %% [markdown]
# ## **Custom GridSearchCV**

# %%
# utility method to get the GridSearchCV object
def grid_search(model,folds,params,scoring):

    grid_search = GridSearchCV(model,
                                cv=folds,
                                param_grid=params,
                                scoring=scoring,
                                n_jobs=-1, verbose=1)
    return grid_search

# %%
# utility function to display the best score and parameters of the GridSearchCV model
def print_best_score_params(model):
    print("Best Score: ", model.best_score_)
    print("Best Hyperparameters: ", model.best_params_)

# %% [markdown]
# ## **Multinomial Naive Bayes Classification**

# %%
# Multinomial Naive Bayes Classification

# create MNB model object
mnb = MultinomialNB()
# fit model
mnb.fit(X_train, y_train)
# display classification report
metric1=[]
display_classification_report(mnb,metric1)
# Out:
# ROC AUC Score Train: 0.95
# ROC AUC Score Test: 0.93
# Train Accuracy : 0.68
# Test Accuracy : 0.64
# Classification Report for Train:
#                precision    recall  f1-score   support
#
#            0       0.56      0.96      0.71      4332
#            1       0.81      0.50      0.62      3110
#            2       0.74      0.89      0.81      3802
#            3       0.97      0.20      0.34      1632
#            4       0.88      0.47      0.62      2928
#
#     accuracy                           0.68     15804
#    macro avg       0.79      0.60      0.62     15804
# weighted avg       0.76      0.68      0.66     15804
#
# Classification Report for Test:
#                precision    recall  f1-score   support
#
#            0       0.52      0.95      0.67      1444
#            1       0.77      0.41      0.54      1037
#            2       0.71      0.85      0.78      1267
#            3       0.96      0.17      0.29       544
#            4       0.86      0.40      0.55       976
#
#     accuracy                           0.64      5268
#    macro avg       0.76      0.56      0.57      5268
# weighted avg       0.72      0.64      0.61      5268

# %% [markdown]
# ## **Logistic Regression Classification**

# %%
# Logistic Regression Classification
log_reg = LogisticRegression(random_state=40,solver='liblinear')
# fit model
log_reg.fit(X_train,y_train)
# display classification report
metric2=[]
display_classification_report(log_reg,metric2)
# Out:
# ROC AUC Score Train: 1.0
# ROC AUC Score Test: 0.99
# Train Accuracy : 0.95
# Test Accuracy : 0.9
# Classification Report for Train:
#                precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      4332
#            1       0.95      0.94      0.95      3110
#            2       0.95      0.98      0.96      3802
#            3       0.95      0.88      0.92      1632
#            4       0.95      0.91      0.93      2928
#
#     accuracy                           0.95     15804
#    macro avg       0.95      0.94      0.94     15804
# weighted avg       0.95      0.95      0.95     15804
#
# Classification Report for Test:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      1444
#            1       0.91      0.89      0.90      1037
#            2       0.92      0.96      0.94      1267
#            3       0.93      0.81      0.87       544
#            4       0.89      0.85      0.87       976
#
#     accuracy                           0.90      5268
#    macro avg       0.91      0.89      0.90      5268
# weighted avg       0.90      0.90      0.90      5268

# %% [markdown]
# ## **Decision Tree Classification**

# %%
# Decision Tree Classification
dtc = DecisionTreeClassifier(random_state=40)
# fit model
dtc.fit(X_train,y_train)
# Decision Tree Classification Report
metric3=[]
display_classification_report(dtc,metric3)
# Out:
# ROC AUC Score Train: 1.0
# ROC AUC Score Test: 0.85
# Train Accuracy : 1.0
# Test Accuracy : 0.76
# Classification Report for Train:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4332
#            1       1.00      1.00      1.00      3110
#            2       1.00      1.00      1.00      3802
#            3       1.00      1.00      1.00      1632
#            4       1.00      1.00      1.00      2928
#
#     accuracy                           1.00     15804
#    macro avg       1.00      1.00      1.00     15804
# weighted avg       1.00      1.00      1.00     15804
#
# Classification Report for Test:
#                precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77      1444
#            1       0.75      0.76      0.76      1037
#            2       0.83      0.83      0.83      1267
#            3       0.74      0.75      0.74       544
#            4       0.67      0.67      0.67       976
#
#     accuracy                           0.76      5268
#    macro avg       0.75      0.76      0.75      5268
# weighted avg       0.76      0.76      0.76      5268

# %% [markdown]
# ## **Random Forest Classification**

# %%
# Random Forest Classification

rf = RandomForestClassifier(n_estimators = 500,random_state=40, n_jobs = -1,oob_score=True)
# fit model
rf.fit(X_train,y_train)

# oob score
print('OOB SCORE :',rf.oob_score_)

# Random Forest Classification Report
metric4=[]
display_classification_report(rf,metric4)
# Out:
# OOB SCORE : 0.8251075677043787
# ROC AUC Score Train: 1.0
# ROC AUC Score Test: 0.98
# Train Accuracy : 1.0
# Test Accuracy : 0.83
# Classification Report for Train:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4332
#            1       1.00      1.00      1.00      3110
#            2       1.00      1.00      1.00      3802
#            3       1.00      1.00      1.00      1632
#            4       1.00      1.00      1.00      2928
#
#     accuracy                           1.00     15804
#    macro avg       1.00      1.00      1.00     15804
# weighted avg       1.00      1.00      1.00     15804
#
# Classification Report for Test:
#                precision    recall  f1-score   support
#
#            0       0.78      0.93      0.85      1444
#            1       0.84      0.78      0.81      1037
#            2       0.85      0.91      0.88      1267
#            3       0.92      0.69      0.79       544
#            4       0.86      0.72      0.78       976
#
#     accuracy                           0.83      5268
#    macro avg       0.85      0.81      0.82      5268
# weighted avg       0.84      0.83      0.83      5268

# %% [markdown]
# # **Hyper parameter tuning with GridSearchCV**

# %% [markdown]
# ## **Multinomial Naive Bayes with GridSearchCV**

# %%
# Multinomial Naive Bayes with GridSearchCV

mnb = MultinomialNB()

mnb_params = {
'alpha': (1, 0.1, 0.01, 0.001, 0.0001)
}

# create gridsearch object
grid_search_mnb = grid_search(mnb, folds, mnb_params, scoring=None)

# fit model
grid_search_mnb.fit(X_train, y_train)

# print best hyperparameters
print_best_score_params(grid_search_mnb)

# Random Forest Classification Report
metric5=[]
display_classification_report(grid_search_mnb,metric5)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Best Score:  0.7549978976369439
# Best Hyperparameters:  {'alpha': 0.1}
# ROC AUC Score Train: 0.98
# ROC AUC Score Test: 0.95
# Train Accuracy : 0.85
# Test Accuracy : 0.76
# Classification Report for Train:
#                precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87      4332
#            1       0.85      0.79      0.82      3110
#            2       0.86      0.91      0.88      3802
#            3       0.89      0.70      0.78      1632
#            4       0.89      0.80      0.84      2928
#
#     accuracy                           0.85     15804
#    macro avg       0.86      0.83      0.84     15804
# weighted avg       0.85      0.85      0.85     15804
#
# Classification Report for Test:
#                precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79      1444
#            1       0.73      0.61      0.66      1037
#            2       0.78      0.87      0.82      1267
#            3       0.84      0.60      0.70       544
#            4       0.79      0.69      0.74       976
#
#     accuracy                           0.76      5268
#    macro avg       0.77      0.73      0.74      5268
# weighted avg       0.76      0.76      0.75      5268

# %% [markdown]
# ## **Logistic Regression with GridSearchCV**

# %%
# Logistic Regression with GridSearchCV

# logistic regression
log_reg = LogisticRegression()

# hyperparameter for Logistic Regression
log_params = {'C': [0.01, 1, 10],
          'penalty': ['l1', 'l2'],
          'solver': ['liblinear','newton-cg','saga']
         }

# create gridsearch object
grid_search_log = grid_search(log_reg, folds, log_params, scoring=None)

# fit model
grid_search_log.fit(X_train, y_train)

# print best hyperparameters
print_best_score_params(grid_search_log)

# Random Forest Classification Report
metric6=[]
display_classification_report(grid_search_log,metric6)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best Score:  0.9212220335657278
# Best Hyperparameters:  {'C': 1, 'penalty': 'l1', 'solver': 'saga'}
# ROC AUC Score Train: 1.0
# ROC AUC Score Test: 0.99
# Train Accuracy : 0.94
# Test Accuracy : 0.93
# Classification Report for Train:
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94      4332
#            1       0.93      0.94      0.93      3110
#            2       0.95      0.96      0.96      3802
#            3       0.93      0.90      0.91      1632
#            4       0.93      0.91      0.92      2928
#
#     accuracy                           0.94     15804
#    macro avg       0.94      0.93      0.93     15804
# weighted avg       0.94      0.94      0.94     15804
#
# Classification Report for Test:
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1444
#            1       0.92      0.92      0.92      1037
#            2       0.95      0.97      0.96      1267
#            3       0.91      0.88      0.89       544
#            4       0.91      0.91      0.91       976
#
#     accuracy                           0.93      5268
#    macro avg       0.93      0.92      0.92      5268
# weighted avg       0.93      0.93      0.93      5268

# %% [markdown]
# ## **Decision Tree Classification with GridSearchCV**

# %%
# Decision Tree Classification wuth GridSearchCV

dtc = DecisionTreeClassifier(random_state=40)

dtc_params = {
    'max_depth': [5,10,20,30],
    'min_samples_leaf': [5,10,20,30]
}

# create gridsearch object
grid_search_dtc = grid_search(dtc, folds, dtc_params, scoring='roc_auc_ovr')

# fit model
grid_search_dtc.fit(X_train, y_train)

# print best hyperparameters
print_best_score_params(grid_search_dtc)

# Random Forest Classification Report
metric7=[]
display_classification_report(grid_search_dtc,metric7)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best Score:  0.9320923433765378
# Best Hyperparameters:  {'max_depth': 20, 'min_samples_leaf': 30}
# ROC AUC Score Train: 0.97
# ROC AUC Score Test: 0.94
# Train Accuracy : 0.81
# Test Accuracy : 0.77
# Classification Report for Train:
#                precision    recall  f1-score   support
#
#            0       0.82      0.81      0.82      4332
#            1       0.80      0.84      0.82      3110
#            2       0.85      0.86      0.86      3802
#            3       0.74      0.74      0.74      1632
#            4       0.78      0.73      0.76      2928
#
#     accuracy                           0.81     15804
#    macro avg       0.80      0.80      0.80     15804
# weighted avg       0.81      0.81      0.81     15804
#
# Classification Report for Test:
#                precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78      1444
#            1       0.75      0.82      0.78      1037
#            2       0.83      0.84      0.84      1267
#            3       0.70      0.70      0.70       544
#            4       0.73      0.68      0.70       976
#
#     accuracy                           0.77      5268
#    macro avg       0.76      0.76      0.76      5268
# weighted avg       0.77      0.77      0.77      5268

# %% [markdown]
# ## **Random Forest Classifier with GridSearchCV**

# %%
# Random Forest Classifier with GridSearchCV

rfc = RandomForestClassifier(random_state=40, n_jobs = -1,oob_score=True)

# hyperparameters for Random Forest
rfc_params = {'max_depth': [10, 20],
              'min_samples_leaf': [5, 10],
              'n_estimators': [100, 200]}

# create gridsearch object
grid_search_rfc = grid_search(rfc, folds, rfc_params, scoring='roc_auc_ovr')

# fit model
grid_search_rfc.fit(X_train, y_train)

# oob score
print('OOB SCORE :',grid_search_rfc.best_estimator_.oob_score_)

# print best hyperparameters
print_best_score_params(grid_search_rfc)

# Random Forest Classification Report
metric8=[]
display_classification_report(grid_search_rfc,metric8)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# OOB SCORE : 0.7644267274107821
# Best Score:  0.966356807096593
# Best Hyperparameters:  {'max_depth': 20, 'min_samples_leaf': 5, 'n_estimators': 200}
# ROC AUC Score Train: 0.99
# ROC AUC Score Test: 0.97
# Train Accuracy : 0.85
# Test Accuracy : 0.77
# Classification Report for Train:
#                precision    recall  f1-score   support
#
#            0       0.76      0.97      0.85      4332
#            1       0.88      0.84      0.86      3110
#            2       0.87      0.93      0.90      3802
#            3       0.97      0.55      0.70      1632
#            4       0.93      0.72      0.81      2928
#
#     accuracy                           0.85     15804
#    macro avg       0.88      0.80      0.83     15804
# weighted avg       0.86      0.85      0.84     15804
#
# Classification Report for Test:
#                precision    recall  f1-score   support
#
#            0       0.67      0.95      0.79      1444
#            1       0.79      0.70      0.74      1037
#            2       0.81      0.89      0.85      1267
#            3       0.95      0.45      0.62       544
#            4       0.87      0.60      0.71       976
#
#     accuracy                           0.77      5268
#    macro avg       0.82      0.72      0.74      5268
# weighted avg       0.80      0.77      0.76      5268

# %% [markdown]
# # **Model inference**

# %% [markdown]
# #### **Consolidated view of all the models and their metrics**

# %%
table = {'Metric': ['ROC_AUC Score(Train)','ROC_AUC Score(Test)',
                    'Accuracy(Train)','Accuracy(Test)',
                    'Precision(Train)','Precision(Test)',
                    'Recall(Train)','Recall(Test)',
                    'F1-Score(Train)','F1-Score(Test)'
                   ],
        'Multinomial Naive Bayes': metric1
        }

mnb_metric = pd.DataFrame(table ,columns = ['Metric', 'Multinomial Naive Bayes'] )
log_metric = pd.Series(metric2, name = 'Logistic Regression')
dtc_metric = pd.Series(metric3, name = 'Decision Tree Classifier')
rfc_metric = pd.Series(metric4, name = 'Random Forest Classifier')
grid_mnb_metric = pd.Series(metric5, name = 'Multinomial Naive Bayes with GridSearchCV')
grid_log_metric = pd.Series(metric6, name = 'Logistic Regression with GridSearchCV')
grid_dtc_metric = pd.Series(metric7, name = 'Decision Tree Classifier with GridSearchCV')
grid_rfc_metric = pd.Series(metric8, name = 'Random Forest Classifier with GridSearchCV')

final_metric = pd.concat([mnb_metric,log_metric,dtc_metric,rfc_metric,
                         grid_mnb_metric,grid_log_metric,grid_dtc_metric,grid_rfc_metric], axis = 1)

final_metric
# Out:
#                  Metric  Multinomial Naive Bayes  Logistic Regression  \
# 0  ROC_AUC Score(Train)                     0.95                 1.00
# 1   ROC_AUC Score(Test)                     0.93                 0.99
# 2       Accuracy(Train)                     0.68                 0.95
# 3        Accuracy(Test)                     0.64                 0.90
# 4      Precision(Train)                     0.76                 0.95
# 5       Precision(Test)                     0.72                 0.90
# 6         Recall(Train)                     0.68                 0.95
# 7          Recall(Test)                     0.64                 0.90
# 8       F1-Score(Train)                     0.66                 0.95
# 9        F1-Score(Test)                     0.61                 0.90
#
#    Decision Tree Classifier  Random Forest Classifier  \
# 0                      1.00                      1.00
# 1                      0.85                      0.98
# 2                      1.00                      1.00
# 3                      0.76                      0.83
# 4                      1.00                      1.00
# 5                      0.76                      0.84
# 6                      1.00                      1.00
# 7                      0.76                      0.83
# 8                      1.00                      1.00
# 9                      0.76                      0.83
#
#    Multinomial Naive Bayes with GridSearchCV  \
# 0                                       0.98
# 1                                       0.95
# 2                                       0.85
# 3                                       0.76
# 4                                       0.85
# 5                                       0.76
# 6                                       0.85
# 7                                       0.76
# 8                                       0.85
# 9                                       0.75
#
#    Logistic Regression with GridSearchCV  \
# 0                                   1.00
# 1                                   0.99
# 2                                   0.94
# 3                                   0.93
# 4                                   0.94
# 5                                   0.93
# 6                                   0.94
# 7                                   0.93
# 8                                   0.94
# 9                                   0.93
#
#    Decision Tree Classifier with GridSearchCV  \
# 0                                        0.97
# 1                                        0.94
# 2                                        0.81
# 3                                        0.77
# 4                                        0.81
# 5                                        0.77
# 6                                        0.81
# 7                                        0.77
# 8                                        0.81
# 9                                        0.77
#
#    Random Forest Classifier with GridSearchCV
# 0                                        0.99
# 1                                        0.97
# 2                                        0.85
# 3                                        0.77
# 4                                        0.86
# 5                                        0.80
# 6                                        0.85
# 7                                        0.77
# 8                                        0.84
# 9                                        0.76

# %%
# Melt the DataFrame for better plotting with plotly
df_melted = final_metric.melt(id_vars="Metric", var_name="Model", value_name="Score")

# Create the line plot
fig = px.line(df_melted, x="Metric", y="Score", color="Model", markers=True,
              title="Model Performance Metrics")

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5d6b4554-cae9-4807-9355-9404563181ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d6b4554-cae9-4807-9355-9404563181ec")) {                    Plotly.newPlot(                        "5d6b4554-cae9-4807-9355-9404563181ec",                        [{"hovertemplate":"Model=Multinomial Naive Bayes\u003cbr\u003eMetric=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Multinomial Naive Bayes","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Multinomial Naive Bayes","orientation":"v","showlegend":true,"x":["ROC_AUC Score(Train)","ROC_AUC Score(Test)","Accuracy(Train)","Accuracy(Test)","Precision(Train)","Precision(Test)","Recall(Train)","Recall(Test)","F1-Score(Train)","F1-Score(Test)"],"xaxis":"x","y":[0.95,0.93,0.68,0.64,0.76,0.72,0.68,0.64,0.66,0.61],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Logistic Regression\u003cbr\u003eMetric=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Logistic Regression","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Logistic Regression","orientation":"v","showlegend":true,"x":["ROC_AUC Score(Train)","ROC_AUC Score(Test)","Accuracy(Train)","Accuracy(Test)","Precision(Train)","Precision(Test)","Recall(Train)","Recall(Test)","F1-Score(Train)","F1-Score(Test)"],"xaxis":"x","y":[1.0,0.99,0.95,0.9,0.95,0.9,0.95,0.9,0.95,0.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Decision Tree Classifier\u003cbr\u003eMetric=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Decision Tree Classifier","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Decision Tree Classifier","orientation":"v","showlegend":true,"x":["ROC_AUC Score(Train)","ROC_AUC Score(Test)","Accuracy(Train)","Accuracy(Test)","Precision(Train)","Precision(Test)","Recall(Train)","Recall(Test)","F1-Score(Train)","F1-Score(Test)"],"xaxis":"x","y":[1.0,0.85,1.0,0.76,1.0,0.76,1.0,0.76,1.0,0.76],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Random Forest Classifier\u003cbr\u003eMetric=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Random Forest Classifier","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Random Forest Classifier","orientation":"v","showlegend":true,"x":["ROC_AUC Score(Train)","ROC_AUC Score(Test)","Accuracy(Train)","Accuracy(Test)","Precision(Train)","Precision(Test)","Recall(Train)","Recall(Test)","F1-Score(Train)","F1-Score(Test)"],"xaxis":"x","y":[1.0,0.98,1.0,0.83,1.0,0.84,1.0,0.83,1.0,0.83],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Multinomial Naive Bayes with GridSearchCV\u003cbr\u003eMetric=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Multinomial Naive Bayes with GridSearchCV","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"Multinomial Naive Bayes with GridSearchCV","orientation":"v","showlegend":true,"x":["ROC_AUC Score(Train)","ROC_AUC Score(Test)","Accuracy(Train)","Accuracy(Test)","Precision(Train)","Precision(Test)","Recall(Train)","Recall(Test)","F1-Score(Train)","F1-Score(Test)"],"xaxis":"x","y":[0.98,0.95,0.85,0.76,0.85,0.76,0.85,0.76,0.85,0.75],"yaxis":"y","type":"scatter"},{"hovertemplate":"Model=Logistic Regression with GridSearchCV\u003cbr\u003eMetric=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Logistic Regression with GridSearchCV","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symb ...

# %% [markdown]
# ### **Complaint Prediction using the best model above**

# %% [markdown]
# #### **The best model looks to be Logistic Regression with GridSearchCV**

# %%
# raw complaint text
test_complaint= 'I tried to make a transaction at a supermarket retail store, using my chase \
debit/atm card, but the transaction was declined. I am still able to withdraw money out of an \
ATM machine using the same debit card. Please resolve this issue.'

# %%
# vectorize and tf-idf tranform
test = count_vect.transform([test_complaint])
test_tfidf = tfidf_transformer.transform(test)

# %%
# predict
prediction=grid_search_log.predict(test_tfidf)
prediction
# Out:
# array([1])

# %%
topic_mapping[prediction[0]]
# Out:
# 'Credit card or prepaid card'
